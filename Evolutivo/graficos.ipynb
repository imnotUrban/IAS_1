# %% [markdown]
# ### Gráficos de convergencia

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
dfBest = pd.read_csv('TXTmin.txt', sep=" ",header=None)
dfProm = pd.read_csv('TXTprom.txt', sep=" ",header=None)

# %%
fig,ax = plt.subplots(figsize=(22,12))
ax.set_xlabel('numero de iteraciones')
ax.set_ylabel('valor evaluado')
ax.set_title('Gráfico de convergencia')

ax.plot(dfBest, label='Mejores')
ax.plot(dfProm, label='Promedio')
ax.legend()

# %%
print("los mínimos: ")
print(dfBest.tail(5))

print("los promedios: ")
print(dfProm.tail(5))
# Out:
# los mínimos:
#               0
# 2497   8.715242
# 2498  12.122645
# 2499  15.610435
# 2500  11.181895
# 2501   4.316864
# los promedios:
#               0
# 2497  13.262342
# 2498  12.278925
# 2499  13.280068
# 2500  12.016762
# 2501  11.149824
